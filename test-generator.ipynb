# %%
from config import Models
from generator import generate

# %%
schema = {
    "email": str,
    "first name": str,
    "last name": str,
    "password": str,
    "age": int,
    "country": str,
}

prompt = f"""
Create a data set for this schema:

{schema}
"""

# %%
print(generate(prompt, 5, Models.GPT_5_NANO))

# %%
print(generate(prompt, 5, Models.GPT_5_4_MINI))

# %%
print(generate(prompt, 5, Models.CLAUDE_HAIKU_4_5))
# Out:
# ```json
# [
#   {
#     "email": "margaret.chen@example.com",
#     "first name": "Margaret",
#     "last name": "Chen",
#     "password": "Kx7$mPq9nL#vJ2",
#     "age": 34,
#     "country": "Singapore"
#   },
#   {
#     "email": "james.richardson@example.com",
#     "first name": "James",
#     "last name": "Richardson",
#     "password": "Bw4&tRy8fH@dE5",
#     "age": 41,
#     "country": "United Kingdom"
#   },
#   {
#     "email": "sofia.santos@example.com",
#     "first name": "Sofia",
#     "last name": "Santos",
#     "password": "Zc3*pQm6nX!wA1",
#     "age": 28,
#     "country": "Brazil"
#   },
#   {
#     "email": "lars.anderson@example.com",
#     "first name": "Lars",
#     "last name": "Anderson",
#     "password": "Gy9%hKs2vN$jL4",
#     "age": 37,
#     "country": "Sweden"
#   },
#   {
#     "email": "yuki.tanaka@example.com",
#     "first name": "Yuki",
#     "last name": "Tanaka",
#     "password": "Mx5#rCw1oP@kS8",
#     "age": 26,
#     "country": "Japan"
#   }
# ...

# %%
print(generate(prompt, 5, Models.GEMINI_2_5_FLASH_LITE))
